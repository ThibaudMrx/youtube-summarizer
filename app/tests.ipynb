# %%
import os
import whisper
from yt_dlp import YoutubeDL
from pydub import AudioSegment

# %%
def download_audio_ytdlp(youtube_url, output_path="audio.mp3"):
    # Define download options
    ydl_opts = {
        'format': 'bestaudio/best',
        'postprocessors': [
            {   
                'key': 'FFmpegExtractAudio',
                'preferredcodec': 'mp3',
                'preferredquality': '192',
            }
        ],
        'outtmpl': 'audio.%(ext)s',  # Save as 'audio.ext'
    }
    
    # Download the audio
    with YoutubeDL(ydl_opts) as ydl:
        ydl.download([youtube_url])
    
    # Ensure the output file exists
    if not os.path.exists("audio.mp3"):
        raise FileNotFoundError("Audio file not found!")
    
    return output_path

youtubeVideotestURL = 'http://www.youtube.com/watch?v=4FTIVJEBkNY'
download_audio_ytdlp(youtubeVideotestURL)
# Out:
# [youtube] Extracting URL: http://www.youtube.com/watch?v=4FTIVJEBkNY
# [youtube] 4FTIVJEBkNY: Downloading webpage
# [youtube] 4FTIVJEBkNY: Downloading ios player API JSON
# [youtube] 4FTIVJEBkNY: Downloading mweb player API JSON
# [youtube] 4FTIVJEBkNY: Downloading m3u8 information
# [info] 4FTIVJEBkNY: Downloading 1 format(s): 251
# [download] audio.webm has already been downloaded
# [download] 100% of    9.53MiB
# ERROR: Postprocessing: ffprobe and ffmpeg not found. Please install or provide the path using --ffmpeg-location
# ---------------------------------------------------------------------------
# PostProcessingError                       Traceback (most recent call last)
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:3567, in YoutubeDL.process_info(self, info_dict)
#    3566 try:
# -> 3567     replace_info_dict(self.post_process(dl_filename, info_dict, files_to_move))
#    3568 except PostProcessingError as err:
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:3751, in YoutubeDL.post_process(self, filename, info, files_to_move)
#    3750 info['__files_to_move'] = files_to_move or {}
# -> 3751 info = self.run_all_pps('post_process', info, additional_pps=info.get('__postprocessors'))
#    3752 info = self.run_pp(MoveFilesAfterDownloadPP(self), info)
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:3733, in YoutubeDL.run_all_pps(self, key, info, additional_pps)
#    3732 for pp in (additional_pps or []) + self._pps[key]:
# -> 3733     info = self.run_pp(pp, info)
#    3734 return info
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:3711, in YoutubeDL.run_pp(self, pp, infodict)
#    3710 try:
# -> 3711     files_to_delete, infodict = pp.run(infodict)
#    3712 except PostProcessingError as e:
#    3713     # Must be True and not 'only_download'
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\yt_dlp\postprocessor\common.py:22, in PostProcessorMetaClass.run_wrapper.<locals>.run(self, info, *args, **kwargs)
#      21 self._hook_progress({'status': 'started'}, info_copy)
# ---> 22 ret = func(self, info, *args, **kwargs)
#      23 if ret is not None:
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\yt_dlp\postprocessor\common.py:127, in PostProcessor._restrict_to.<locals>.decorator.<locals>.wrapper(self, info)
#     126 if allowed[format_type]:
# --> 127     return func(self, info)
#     128 else:
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\yt_dlp\postprocessor\ffmpeg.py:493, in FFmpegExtractAudioPP.run(self, information)
#     491     return [], information
# --> 493 filecodec = self.get_audio_codec(path)
#     494 if filecodec is None:
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\yt_dlp\postprocessor\ffmpeg.py:241, in FFmpegPostProcessor.get_audio_codec(self, path)
#     240 if not self.probe_available and not self.available:
# --> 241     raise PostProcessingError('ffprobe and ffmpeg not found. Please install or provide the path using --ffmpeg-location')
#     242 try:
#
# PostProcessingError: ffprobe and ffmpeg not found. Please install or provide the path using --ffmpeg-location
#
# During handling of the above exception, another exception occurred:
#
# DownloadError                             Traceback (most recent call last)
# Cell In[14], line 26
#      23     return output_path
#      25 youtubeVideotestURL = 'http://www.youtube.com/watch?v=4FTIVJEBkNY'
# ---> 26 download_audio_ytdlp(youtubeVideotestURL)
#
# Cell In[14], line 17, in download_audio_ytdlp(youtube_url, output_path)
#      15 # Download the audio
#      16 with YoutubeDL(ydl_opts) as ydl:
# ---> 17     ydl.download([youtube_url])
#      19 # Ensure the output file exists
#      20 if not os.path.exists("audio.mp3"):
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:3615, in YoutubeDL.download(self, url_list)
#    3612     raise SameFileError(outtmpl)
#    3614 for url in url_list:
# -> 3615     self.__download_wrapper(self.extract_info)(
#    3616         url, force_generic_extractor=self.params.get('force_generic_extractor', False))
#    3618 return self._download_retcode
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:3588, in YoutubeDL.__download_wrapper.<locals>.wrapper(*args, **kwargs)
#    3585 @functools.wraps(func)
#    3586 def wrapper(*args, **kwargs):
#    3587     try:
# -> 3588         res = func(*args, **kwargs)
#    3589     except CookieLoadError:
#    3590         raise
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1623, in YoutubeDL.extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1621             raise ExistingVideoReached
#    1622         break
# -> 1623     return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1624 else:
#    1625     extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1634, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1632 while True:
#    1633     try:
# -> 1634         return func(self, *args, **kwargs)
#    1635     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1636         raise
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1790, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1788 if process:
#    1789     self._wait_for_video(ie_result)
# -> 1790     return self.process_ie_result(ie_result, download, extra_info)
#    1791 else:
#    1792     return ie_result
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1849, in YoutubeDL.process_ie_result(self, ie_result, download, extra_info)
#    1847 if result_type == 'video':
#    1848     self.add_extra_info(ie_result, extra_info)
# -> 1849     ie_result = self.process_video_result(ie_result, download=download)
#    1850     self._raise_pending_errors(ie_result)
#    1851     additional_urls = (ie_result or {}).get('additional_urls')
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:3021, in YoutubeDL.process_video_result(self, info_dict, download)
#    3019 downloaded_formats.append(new_info)
#    3020 try:
# -> 3021     self.process_info(new_info)
#    3022 except MaxDownloadsReached:
#    3023     max_downloads_reached = True
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:177, in _catch_unsafe_extension_error.<locals>.wrapper(self, *args, **kwargs)
#     174 @functools.wraps(func)
#     175 def wrapper(self, *args, **kwargs):
#     176     try:
# --> 177         return func(self, *args, **kwargs)
#     178     except _UnsafeExtensionError as error:
#     179         self.report_error(
#     180             f'The extracted extension ({error.extension!r}) is unusual '
#     181             'and will be skipped for safety reasons. '
#     182             f'If you believe this is an error{bug_reports_message(",")}')
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:3569, in YoutubeDL.process_info(self, info_dict)
#    3567     replace_info_dict(self.post_process(dl_filename, info_dict, files_to_move))
#    3568 except PostProcessingError as err:
# -> 3569     self.report_error(f'Postprocessing: {err}')
#    3570     return
#    3571 try:
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1092, in YoutubeDL.report_error(self, message, *args, **kwargs)
#    1087 def report_error(self, message, *args, **kwargs):
#    1088     """
#    1089     Do the same as trouble, but prefixes the message with 'ERROR:', colored
#    1090     in red if stderr is a tty file.
#    1091     """
# -> 1092     self.trouble(f'{self._format_err("ERROR:", self.Styles.ERROR)} {message}', *args, **kwargs)
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1031, in YoutubeDL.trouble(self, message, tb, is_error)
#    1029     else:
#    1030         exc_info = sys.exc_info()
# -> 1031     raise DownloadError(message, exc_info)
#    1032 self._download_retcode = 1
#
# DownloadError: ERROR: Postprocessing: ffprobe and ffmpeg not found. Please install or provide the path using --ffmpeg-location

# %%
# Out:
# Downloading audio from http://www.youtubed.com/watch?v=4FTIVJEBkNY...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 22
#      20 # Example
#      21 youtube_url = 'http://www.youtubed.com/watch?v=4FTIVJEBkNY' # Du détroit de Béring à l'Arctique : les ambitions russes | Le Dessous des Cartes | ARTE
# ---> 22 audio_path = download_audio(youtube_url)
#      23 if audio_path:
#      24     print(f"Audio downloaded to {audio_path}")
#
# Cell In[5], line 4, in download_audio(youtube_url, output_path)
#       2 yt = YouTube(youtube_url)
#       3 print(f"Downloading audio from {youtube_url}...")
# ----> 4 audio_stream = yt.streams.filter(only_audio=True)
#       5 print(audio_stream)
#       6 if not audio_stream:
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\pytube\__main__.py:296, in YouTube.streams(self)
#     291 """Interface to query both adaptive (DASH) and progressive streams.
#     292
#     293 :rtype: :class:`StreamQuery <StreamQuery>`.
#     294 """
#     295 self.check_availability()
# --> 296 return StreamQuery(self.fmt_streams)
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\pytube\__main__.py:176, in YouTube.fmt_streams(self)
#     172     return self._fmt_streams
#     174 self._fmt_streams = []
# --> 176 stream_manifest = extract.apply_descrambler(self.streaming_data)
#     178 # If the cached js doesn't work, try fetching a new js file
#     179 # https://github.com/pytube/pytube/issues/1054
#     180 try:
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\pytube\__main__.py:160, in YouTube.streaming_data(self)
#     158     return self.vid_info['streamingData']
#     159 else:
# --> 160     self.bypass_age_gate()
#     161     return self.vid_info['streamingData']
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\pytube\__main__.py:257, in YouTube.bypass_age_gate(self)
#     251 """Attempt to update the vid_info by bypassing the age gate."""
#     252 innertube = InnerTube(
#     253     client='ANDROID_EMBED',
#     254     use_oauth=self.use_oauth,
#     255     allow_cache=self.allow_oauth_cache
#     256 )
# --> 257 innertube_response = innertube.player(self.video_id)
#     259 playability_status = innertube_response['playabilityStatus'].get('status', None)
#     261 # If we still can't access the video, raise an exception
#     262 # (tier 3 age restriction)
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\pytube\innertube.py:448, in InnerTube.player(self, video_id)
#     444 query = {
#     445     'videoId': video_id,
#     446 }
#     447 query.update(self.base_params)
# --> 448 return self._call_api(endpoint, query, self.base_data)
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\pytube\innertube.py:390, in InnerTube._call_api(self, endpoint, query, data)
#     386         headers['Authorization'] = f'Bearer {self.access_token}'
#     388 headers.update(self.header)
# --> 390 response = request._execute_request(
#     391     endpoint_url,
#     392     'POST',
#     393     headers=headers,
#     394     data=data
#     395 )
#     396 return json.loads(response.read())
#
# File c:\Users\thiba\Desktop\travailWindows\youtubeSummarizer\youtube-summarizer\.venv\Lib\site-packages\pytube\request.py:37, in _execute_request(url, method, headers, data, timeout)
#      35 else:
#      36     raise ValueError("Invalid URL")
# ---> 37 return urlopen(request, timeout=timeout)
#
# File C:\Program Files\Python312\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File C:\Program Files\Python312\Lib\urllib\request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File C:\Program Files\Python312\Lib\urllib\request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     627 # According to RFC 2616, "2xx" code indicates that the client's
#     628 # request was successfully received, understood, and accepted.
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File C:\Program Files\Python312\Lib\urllib\request.py:559, in OpenerDirector.error(self, proto, *args)
#     557 if http_err:
#     558     args = (dict, 'default', 'http_error_default') + orig_args
# --> 559     return self._call_chain(*args)
#
# File C:\Program Files\Python312\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File C:\Program Files\Python312\Lib\urllib\request.py:639, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     638 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden
